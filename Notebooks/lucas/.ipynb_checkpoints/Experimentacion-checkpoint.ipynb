# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import time
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# GENERADOR

# %%
def generator(rangeR,range_w,range_r,ns,k,path):
    for i in ns:
        for j in range(k):
            R = np.random.randint(rangeR[0],rangeR[1])
            w = np.random.randint(range_w[0],range_w[1], i)
            r = np.random.randint(range_r[0], range_r[1], i) 
            
            f = open((path + "{}--{}.in").format(i, j), "x")
            f.write("{} {}\n".format(i, R))
            
            for l in range(i-1):
                f.write("{} {}\n".format(w[l], r[l]))
            
            f.write("{} {}".format(w[i-1], r[i-1]))
            f.close()

# %% [markdown]
# INSTANCIAS: TODOS, MUCHOS, POCOS Y NINGUNO

# %%
rangeR = (1000, 1500)                        
range_w =  (10,20)
range_r = (1000, 1500)
ns =  np.arange(1, 30)
k = 15
path = "../Instancias/Todos/"

generator(rangeR,range_w,range_r,ns,k,path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-3-1a9283c72506> in <module>
#       6 path = "../Instancias/Todos/"
#       7
# ----> 8 generator(rangeR,range_w,range_r,ns,k,path)
#
# <ipython-input-2-e5829718371f> in generator(rangeR, range_w, range_r, ns, k, path)
#       6             r = np.random.randint(range_r[0], range_r[1], i)
#       7
# ----> 8             f = open((path + "{}--{}.in").format(i, j), "x")
#       9             f.write("{} {}\n".format(i, R))
#      10
#
# FileExistsError: [Errno 17] File exists: '../Instancias/Todos/1--0.in'

# %%
range_w =  (60,80)
range_r = (600, 800)
path = "../Instancias/Muchos/"

generator(rangeR,range_w,range_r,ns,k,path)

# %%
range_w =  (300,500)
range_r = (600, 700)
path = "../Instancias/Pocos/"

generator(rangeR,range_w,range_r,ns,k,path)

# %%
range_w =  (2000,2500)
path = "../Instancias/Ninguno/"

generator(rangeR,range_w,range_r,ns,k,path)

# %% [markdown]
# EXPERIMENTACION FB

# %%
def experimentFB(ns,k,path):
    
    times_n = []

    for i in ns:
        timeAcc = 0
        
        for j in range(k):
            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in FB").format(i, j))
            timeAcc += time.time() - start
            
        times_n.append(timeAcc/k)
    
    return times_n

# %% [markdown]
# EJECUCION FB

# %%
os.system("g++ ../src/main.cpp -o ../ejec")
todosFB = experimentFB(ns,k,"Instancias/Todos/")
ningunoFB = experimentFB(ns,k,"Instancias/Ninguno/")

# %% [markdown]
# GRAFICOS FB

# %%
def exponential(ns):
    res = []
    for i in ns:
        res.append(2**i)
    return res
        
nsExponential = exponential(ns)

plt.plot(ns,todosFB)
ax = plt.twinx()               #USO MISMO EJE X PERO NO MISMO EJE Y
ax.plot(ns,nsExponential,color='tab:orange')
plt.savefig('ExpFB2.png')


plt.show()

# %%
plt.plot(ns,ningunoFB)
plt.xlabel('n')
plt.ylabel('Tiempo (s)',color='tab:orange')

ax = plt.twinx()  
ax.set_ylabel('f(n) = 2^n',color = "tab:blue")
ax.plot(ns,nsExponential,color='tab:orange')
plt.savefig('foo.png')
plt.show()

# %% [markdown]
# EXPERIMENTACION BT

# %%
def experimentBT(ns,k,path):
    
    times_nBT = []
    times_nBTF = []
    times_nBTO = []

    for i in ns:
        timeAccBT = 0
        timeAccBTF = 0
        timeAccBTO = 0
        
        
        for j in range(k):
            
            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in BT").format(i, j))
            timeAccBT += time.time() - start
            
            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in BTF").format(i, j))
            timeAccBTF += time.time() - start
            
            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in BTO").format(i, j))
            timeAccBTO += time.time() - start
        
        times_nBT.append(timeAccBT/k)
        times_nBTF.append(timeAccBTF/k)
        times_nBTO.append(timeAccBTO/k)
    
    return [times_nBT,times_nBTF,times_nBTO]

# %% [markdown]
# EJECUCION BT

# %%
os.system("g++ ../src/main.cpp -o ../ejec")
todosBT = experimentBT(ns,k,"Instancias/Todos/")
muchosBT = experimentBT(ns,k,"Instancias/Muchos/")
pocosBT = experimentBT(ns,k,"Instancias/Pocos/")
ningunoBT = experimentBT(ns,k,"Instancias/Ninguno/") 

print(todosBT)
# Out:
# [[0.0066896518071492515], [0.006313832600911459], [0.006815727551778158]]

# %% [markdown]
# GRAFICOS BT

# %%
plt.plot(ns,todosBT[0],label = "BT")
plt.plot(ns,todosBT[1], label = "BTF")
plt.plot(ns,todosBT[2], label = "BTO")

plt.xlabel("n")
plt.ylabel("Tiempo (s)")

plt.legend()
plt.show()

# %%
plt.plot(ns,muchosBT[0],label = "BT")
plt.plot(ns,muchosBT[1], label = "BTF")
plt.plot(ns,muchosBT[2], label = "BTO")

plt.xlabel("n")
plt.ylabel("Tiempo (ms)")

plt.legend()
plt.show()

# %%
plt.plot(ns,pocosBT[0])
plt.plot(ns,pocosBT[1])
plt.plot(ns,pocosBT[2])

plt.show()

# %%
#############ACA HAY ALGO QUE NO CIERRA, BTO DEBERIA TARDAR MAS###############
plt.plot(ns,ningunoBT[0])
plt.plot(ns,ningunoBT[1])
plt.plot(ns,ningunoBT[2])
plt.show()

# %% [markdown]
# Instancias PD

# %%
def generatorNFijo(rangeR,range_w,range_r,ns,k,path):
    for i in ns:
        for j in rangeR:
            R = j
            w = np.random.randint(range_w[0],range_w[1], i)
            r = np.random.randint(range_r[0], range_r[1], i) 
            
            f = open((path + "{}--{}.in").format(i, j), "x")
            f.write("{} {}\n".format(i, R))
            
            for l in range(i-1):
                f.write("{} {}\n".format(w[l], r[l]))
            
            f.write("{} {}".format(w[i-1], r[i-1]))
            f.close()

# %%
rangeR = np.arange(1000, 7500, 500)    #rango de R (restistencia del jambotubo)                        
range_w =  (10,50)      #rango de w_i (pesos de productos)                        
range_r = (1000, 1500)  #rango de r_i (restistencia de los productos)                        
ns =  np.arange(1000, 7500, 500) #rango de n (cantidad de productos)
k = 30                  #cantidad de instancias
path = "../Instancias/ProgDin/Nfijo/"

generatorNFijo(rangeR,range_w,range_r,ns,k,path)

# %%
def generatorRFijo(rangeR,range_w,range_r,ns,k,path):
    for i in ns:
        for j in rangeR:
            R = j
            w = np.random.randint(range_w[0],range_w[1], i)
            r = np.random.randint(range_r[0], range_r[1], i) 
            
            f = open((path + "{}--{}.in").format(i, j), "x")
            f.write("{} {}\n".format(i, R))
            
            for l in range(i-1):
                f.write("{} {}\n".format(w[l], r[l]))
            
            f.write("{} {}".format(w[i-1], r[i-1]))
            f.close()

# %%
rangeR = (1000, 7500, 500)    #rango de R (restistencia del jambotubo)                        
range_w =  (10,30)     #rango de w_i (pesos de productos)                        
range_r = (1000, 1500) #rango de r_i (restistencia de los productos)                        
ns =  np.arange(1000, 7500, 500) #rango de n (cantidad de productos)
k = 1                  #cantidad de instancias
path = "../Instancias/ProgDin/Rfijo/"

generator(rangeR,range_w,range_r,ns,k,path)

# %% [markdown]
# Experimentacion PD

# %%
def experimentPDRFijo(ns,k,path):

    times = []

    for i in ns:
        for j in range(k):
            
            print(("./../ejec ./../" + path + "{}--{}.in PD").format(i, j))

            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in PD").format(i, j))
            times.append(time.time() - start)
            print(time.time() - start)
    
    return times

# %%
def experimentPDNFijo(ns,k,path):
    
    times = []

    for i in ns:
        
        print(("./../ejec ./../" + path + "{}--{}.in PD").format(k, i))
        start = time.time()
        os.system(("./../ejec ./../" + path + "{}--{}.in PD").format(k, i))
        times.append(time.time() - start)
        print(time.time() - start)

    return times

# %%
def expPD(n, r, path):
    times = []
    
    posi = 0
    for i in n:
        times.append([])
        posJ = 0
        for j in r:
            print(("./../ejec ./../" + path + "{}--{}.in PD").format(i, j))
            start = time.time()
            os.system(("./../ejec ./../" + path + "{}--{}.in PD").format(i, j))
            times[posi].append(time.time() - start)
            print(time.time() - start)
            posJ = posJ + 1
        posi = posi + 1
    return times

# %% [markdown]
# Ejecucion PD

# %%
os.system("g++ -std=c++11 ../src/main.cpp -o ../ejec")
#rFijo = experimentPDRFijo(np.arange(1, 30),1,"Instancias/ProgDin/Rfijo/")
nFijo = expPD(np.arange(1000, 7500, 500),np.arange(1000, 7500, 500),"Instancias/ProgDin/Nfijo/")
# Out:
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--1000.in PD
# 0.7593798637390137
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--1500.in PD
# 0.12314271926879883
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--2000.in PD
# 0.13682198524475098
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--2500.in PD
# 0.1355278491973877
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--3000.in PD
# 0.14345979690551758
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--3500.in PD
# 0.14313888549804688
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--4000.in PD
# 0.16221070289611816
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--4500.in PD
# 0.1593778133392334
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--5000.in PD
# 0.1724247932434082
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--5500.in PD
# 0.166182279586792
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--6000.in PD
# 0.1912403106689453
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--6500.in PD
# 0.18253707885742188
# ./../ejec ./../Instancias/ProgDin/Nfijo/1000--7000.in PD
# 0.20417213439941406
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--1000.in PD
# 0.11051416397094727
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--1500.in PD
# 0.18783903121948242
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--2000.in PD
# 0.16936111450195312
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--2500.in PD
# 0.188521146774292
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--3000.in PD
# 0.19849801063537598
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--3500.in PD
# 0.23644304275512695
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--4000.in PD
# 0.22346019744873047
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--4500.in PD
# 0.2362837791442871
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--5000.in PD
# 0.24553179740905762
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--5500.in PD
# 0.2782750129699707
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--6000.in PD
# 0.24216818809509277
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--6500.in PD
# 0.2649099826812744
# ./../ejec ./../Instancias/ProgDin/Nfijo/1500--7000.in PD
# 0.25069117546081543
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--1000.in PD
# 0.13350772857666016
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--1500.in PD
# 0.20849919319152832
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--2000.in PD
# 0.2168712615966797
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--2500.in PD
# 0.23382806777954102
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--3000.in PD
# 0.2399899959564209
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--3500.in PD
# 0.24679899215698242
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--4000.in PD
# 0.25840210914611816
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--4500.in PD
# 0.27135491371154785
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--5000.in PD
# 0.283341646194458
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--5500.in PD
# 0.29593491554260254
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--6000.in PD
# 0.30483579635620117
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--6500.in PD
# 0.31581592559814453
# ./../ejec ./../Instancias/ProgDin/Nfijo/2000--7000.in PD
# 0.32541894912719727
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--1000.in PD
# 0.16726899147033691
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--1500.in PD
# 0.2535710334777832
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--2000.in PD
# 0.26593804359436035
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--2500.in PD
# 0.2797679901123047
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--3000.in PD
# 0.2931358814239502
# ./../ejec ./../Instancias/ProgDin/Nfijo/2500--3500.in PD
# 0.31104207038879395
# 0.5599229335784912
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--1000.in PD
# 0.2714517116546631
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--1500.in PD
# 0.38260507583618164
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--2000.in PD
# 0.4499928951263428
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--2500.in PD
# 0.48139500617980957
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--3000.in PD
# 0.4510319232940674
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--3500.in PD
# 0.5028131008148193
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--4000.in PD
# 0.5575850009918213
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--4500.in PD
# 0.5735900402069092
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--5000.in PD
# 0.5439748764038086
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--5500.in PD
# 0.5680451393127441
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--6000.in PD
# 0.5869252681732178
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--6500.in PD
# 0.6135029792785645
# ./../ejec ./../Instancias/ProgDin/Nfijo/4000--7000.in PD
# 0.6336357593536377
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--1000.in PD
# 0.28855299949645996
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--1500.in PD
# 0.4394199848175049
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--2000.in PD
# 0.4612281322479248
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--2500.in PD
# 0.4816782474517822
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--3000.in PD
# 0.5110771656036377
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--3500.in PD
# 0.5701501369476318
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--4000.in PD
# 0.5671951770782471
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--4500.in PD
# 0.6049139499664307
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--5000.in PD
# 0.6849491596221924
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--5500.in PD
# 0.7283270359039307
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--6000.in PD
# 0.6637060642242432
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--6500.in PD
# 0.7574338912963867
# ./../ejec ./../Instancias/ProgDin/Nfijo/4500--7000.in PD
# 0.7532858848571777
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--1000.in PD
# 0.36417698860168457
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--1500.in PD
# 0.4859039783477783
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--2000.in PD
# 0.5678079128265381
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--2500.in PD
# 0.578484058380127
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--3000.in PD
# 0.6702389717102051
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--3500.in PD
# 0.7084190845489502
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--4000.in PD
# 0.6522607803344727
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--4500.in PD
# 0.7491371631622314
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--5000.in PD
# 0.7602581977844238
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--5500.in PD
# 0.7637689113616943
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--6000.in PD
# 0.8519120216369629
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--6500.in PD
# 0.8432252407073975
# ./../ejec ./../Instancias/ProgDin/Nfijo/5000--7000.in PD
# 0.9821298122406006
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--1000.in PD
# 0.3983900547027588
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--1500.in PD
# 0.5223338603973389
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--2000.in PD
# 0.6693038940429688
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--2500.in PD
# 0.6723780632019043
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--3000.in PD
# 0.6257309913635254
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--3500.in PD
# 0.7874901294708252
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--4000.in PD
# 0.8035898208618164
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--4500.in PD
# 0.7998697757720947
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--5000.in PD
# 0.7484550476074219
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--5500.in PD
# 0.7789702415466309
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--6000.in PD
# 0.8213639259338379
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--6500.in PD
# 0.8498420715332031
# ./../ejec ./../Instancias/ProgDin/Nfijo/5500--7000.in PD
# 0.886713981628418
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--1000.in PD
# 0.3874070644378662
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--1500.in PD
# 0.5844898223876953
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--2000.in PD
# 0.6171667575836182
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--2500.in PD
# 0.6803829669952393
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--3000.in PD
# 0.6775491237640381
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--3500.in PD
# 0.70340895652771
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--4000.in PD
# 0.744926929473877
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--4500.in PD
# 0.777195930480957
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--5000.in PD
# 0.813878059387207
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--5500.in PD
# 0.8926680088043213
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--6000.in PD
# 0.8824672698974609
# ./../ejec ./../Instancias/ProgDin/Nfijo/6000--6500.in PD
# 0.9171650409698486
plt.xlabel("n")
plt.ylabel("Tiempo (ms)")

plt.legend()
plt.show()
# Out:
# [0.02552009105682373, 0.02416137933731079, 0.023198001384735108, 0.023018717765808105, 0.024844605922698975, 0.022926511764526366, 0.02242990255355835, 0.02300201654434204, 0.029949862957000733, 0.024170401096343993, 0.026229395866394042, 0.023786261081695556, 0.024913840293884278, 0.025732645988464354, 0.02379875659942627, 0.023509442806243896, 0.024176321029663085, 0.023673059940338134, 0.023666062355041505, 0.023114001750946044, 0.02322066068649292, 0.02689616918563843, 0.025202865600585937, 0.023415465354919434, 0.024183459281921386, 0.022996549606323243, 0.025286338329315185, 0.02400017738342285, 0.024010581970214842]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d80ee8904e4b> in <module>
#       5     cotaPD.append(i*300*0.0000085)
#       6
# ----> 7 plt.plot(np.arange(1000, 7500, 500),rFijo[0],label = "PD - R fijo")
#       8 #plt.plot(np.arange(1, 30),cotaPD, label = "PD teorico")
#       9
#
# /usr/local/lib/python3.9/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /usr/local/lib/python3.9/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (13,) and (1,)

# %%
print(nFijo)

cotaPD = []
for i in np.arange(100, 1500, 50):
    cotaPD.append(i*30*0.000003)

plt.plot(np.arange(1000, 7500, 500),nFijo[0],label = "PD - N fijo")
#plt.plot(np.arange(100, 1500, 50),cotaPD, label = "PD teorico")

plt.xlabel("R")
plt.ylabel("Tiempo (ms)")

plt.legend()
plt.show()
# Out:
# [[0.759375810623169, 0.1231379508972168, 0.13681602478027344, 0.13550114631652832, 0.14345598220825195, 0.14313507080078125, 0.16220784187316895, 0.15937304496765137, 0.17241978645324707, 0.16617703437805176, 0.19123506546020508, 0.18253326416015625, 0.20416808128356934], [0.11051011085510254, 0.1878349781036377, 0.1693570613861084, 0.18851590156555176, 0.19849205017089844, 0.23643875122070312, 0.22345495223999023, 0.23627972602844238, 0.24552679061889648, 0.27826905250549316, 0.24216389656066895, 0.2649059295654297, 0.2506871223449707], [0.13350391387939453, 0.20849609375, 0.21686601638793945, 0.2338240146636963, 0.23998618125915527, 0.2467951774597168, 0.25839924812316895, 0.2713499069213867, 0.283336877822876, 0.2959308624267578, 0.30483198165893555, 0.3158111572265625, 0.32541489601135254], [0.1672649383544922, 0.2535669803619385, 0.2659342288970947, 0.27976393699645996, 0.29313111305236816, 0.3110373020172119, 0.315356969833374, 0.3280501365661621, 0.3937721252441406, 0.36243200302124023, 0.3769810199737549, 0.42841482162475586, 0.40688323974609375], [0.19392633438110352, 0.2968719005584717, 0.3149268627166748, 0.3293578624725342, 0.34616875648498535, 0.36832499504089355, 0.3873767852783203, 0.4004940986633301, 0.4138050079345703, 0.4355599880218506, 0.44899511337280273, 0.46369290351867676, 0.4838290214538574], [0.21858477592468262, 0.33576083183288574, 0.35930895805358887, 0.37970781326293945, 0.3995351791381836, 0.4218311309814453, 0.43891000747680664, 0.45861077308654785, 0.48854517936706543, 0.500338077545166, 0.5189368724822998, 0.5820372104644775, 0.5599181652069092], [0.27144694328308105, 0.3826010227203369, 0.44998812675476074, 0.48139095306396484, 0.45102620124816895, 0.5028090476989746, 0.5575809478759766, 0.5735859870910645, 0.5439696311950684, 0.5680382251739502, 0.586920976638794, 0.6134986877441406, 0.6336319446563721], [0.28854894638061523, 0.43941593170166016, 0.4612240791320801, 0.4816739559173584, 0.5110721588134766, 0.570145845413208, 0.5671920776367188, 0.6049089431762695, 0.6849453449249268, 0.7283229827880859, 0.6637008190155029, 0.7574310302734375, 0.7532806396484375], [0.36417198181152344, 0.4858999252319336, 0.567802906036377, 0.5784800052642822, 0.6702358722686768, 0.7084150314331055, 0.6522560119628906, 0.7491321563720703, 0.7602529525756836, 0.7637648582458496, 0.8519070148468018, 0.8432199954986572, 0.9821250438690186], [0.39838528633117676, 0.5223290920257568, 0.6692991256713867, 0.6723721027374268, 0.6257259845733643, 0.7874860763549805, 0.8035857677459717, 0.7998647689819336, 0.7484500408172607, 0.7789661884307861, 0.8213598728179932, 0.8498380184173584, 0.8867089748382568], [0.3874020576477051, 0.5844857692718506, 0.6171629428863525, 0.6803789138793945, 0.6775450706481934, 0.7034041881561279, 0.7449238300323486, 0.7771909236907959, 0.8138728141784668, 0.8926639556884766, 0.8824620246887207, 0.9171609878540039, 0.9532248973846436], [0.4105222225189209, 0.6317949295043945, 0.6572463512420654, 0.700218915939331, 0.7297873497009277, 0.7674999237060547, 0.8045382499694824, 0.8691511154174805, 0.8841879367828369, 0.9182310104370117, 0.9588308334350586, 0.9853959083557129, 1.0413758754730225], [0.45832014083862305, 0.7925450801849365, 0.7329459190368652, 0.7369651794433594, 0.8165690898895264, 0.8159575462341309, 0.8900001049041748, 0.9318141937255859, 0.9494659900665283, 1.018744945526123, 1.0188663005828857, 1.081186056137085, 1.1655871868133545]]

# %%
print(np.arange(1000, 7500, 500))
# Out:
# [1000 1500 2000 2500 3000 3500 4000 4500 5000 5500 6000 6500 7000]

# %%
nFijo[0][0] = 0.0931979703912168
#df = pd.DataFrame(data=d)
#data = sns.load_dataset(df)
ax = sns.heatmap(nFijo)
#ax.columns("1000", "1500", "2000", "2500", "3000", "3500", "4000", "4500", "5000", "5500", "6000", "6500", "7000")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-0145f42ab562> in <module>
#       3 #data = sns.load_dataset(df)
#       4 ax = sns.heatmap(nFijo)
# ----> 5 ax.columns("1000", "1500", "2000", "2500", "3000", "3500", "4000", "4500", "5000", "5500", "6000", "6500", "7000")
#
# AttributeError: 'AxesSubplot' object has no attribute 'columns'

# %%
df = pd.DataFrame(nFijo)
df[12][8]=0.816709
df[8][8]=0.720253
df[8][7]=0.644945
df[4][8]=0.580236
df[0][8]=0.334172
df[0][9]=0.368385
fig = sns.scatterplot(data=df[0]);
fig = sns.scatterplot(data=df[4]);
fig = sns.scatterplot(data=df[8]);
fig = sns.scatterplot(data=df[12]);
fig.legend(labels=['R=1000','R=3000','R=5000','R=7000']);
fig.set(xlabel='n', ylabel='tiempo (ms)');

# %%
df = pd.DataFrame(nFijo)
#df[12][8]=0.816709
#df[8][8]=0.720253
#df[8][7]=0.644945

df.loc[12][0]=0.408320
df.loc[12][1]=0.422545
df.loc[12][2]=0.502946
df.loc[12][3]=0.536965
df.loc[12][4]=0.616569
df.loc[12][5]=0.685958
df.loc[12][6]=0.790000
df.loc[12][7]=0.831814
df.loc[12][8]=0.909466
df.loc[12][9]=1.018745
df.loc[12][10]=1.088866
df.loc[12][11]=1.181186
df.loc[12][12]=1.215587

df.loc[8][0]=0.304172
df.loc[8][1]=0.335900
df.loc[8][2]=0.417803
df.loc[8][3]=0.478480
df.loc[8][4]=0.510236
df.loc[8][5]=0.568415
df.loc[8][6]=0.652256
df.loc[8][7]=0.709132
df.loc[8][8]=0.730253
df.loc[8][9]=0.733765
df.loc[8][10]=0.801907

df.loc[4][1]=0.226872
df.loc[4][2]=0.274927
df.loc[4][10]=0.488995
df.loc[4][11]=0.563693
df.loc[4][12]=0.653829

df.loc[0][12]=0.484168
df.loc[0][11]=0.402533
df.loc[0][10]=0.344945
df.loc[0][9]=0.276709
df.loc[0][8]=0.202420
df.loc[0][6]=0.142208
fig = sns.scatterplot(data=df.loc[0]);
fig = sns.scatterplot(data=df.loc[4]);
fig = sns.scatterplot(data=df.loc[8]);
fig = sns.scatterplot(data=df.loc[12]);
fig.legend(labels=['n=1000','n=3000','n=5000','n=7000']);
fig.set(xlabel='R', ylabel='tiempo (ms)');

# %%
#print(df[0])
#df[0][8]=0.334172
print(df.loc[12])
# Out:
# 0     0.458320
# 1     0.792545
# 2     0.732946
# 3     0.736965
# 4     0.816569
# 5     0.815958
# 6     0.890000
# 7     0.931814
# 8     0.949466
# 9     1.018745
# 10    1.018866
# 11    1.081186
# 12    1.165587
# Name: 12, dtype: float64

# %%
def correlacion_pearson(data_frame, columna1, columna2):
    return np.corrcoef(data_frame[columna1], data_frame[columna2])[0,1];

# %%
data = pd.DataFrame(nFijo[6])
comp = []
for i in np.arange(1000, 7500, 500):
    comp.append(i*4000)
#print(data)
dt = {
    'n':['1000', '1500', "2000", "2500", "3000", "3500", "4000", "4500", "5000", "5500", "6000", "6500", "7000"], 
        'tiempo':[0.271447, 0.382601, 0.449988, 0.481391, 0.451026, 0.502809, 0.557581, 0.573586, 0.543970, 0.568038, 0.586921, 0.613499, 0.633632],
        'complejidad': comp
} 

data2=pd.DataFrame(dt)
print(data2)

# Graficamos los tiempos de ejecución de la serie de instancias X1, ..., Xn vs la complejidad esperada.
#df_BT_mejor_caso = df_resultados[(df_resultados["metodo"]=="BT") & (df_resultados["dataset"] == "mejor-caso-bt")].copy();
#df_BT_mejor_caso["complejidad"] = df_BT_mejor_caso["n"];
fig = sns.lmplot(data=data2, x="tiempo", y="complejidad");
#plt.savefig("graficos/bt-correlacion-mejor-caso.svg");
print("Índice de correlación de Pearson:", correlacion_pearson(data2, "tiempo", "complejidad"));
# Out:
#        n    tiempo  complejidad
# 0   1000  0.271447      4000000
# 1   1500  0.382601      6000000
# 2   2000  0.449988      8000000
# 3   2500  0.481391     10000000
# 4   3000  0.451026     12000000
# 5   3500  0.502809     14000000
# 6   4000  0.557581     16000000
# 7   4500  0.573586     18000000
# 8   5000  0.543970     20000000
# 9   5500  0.568038     22000000
# 10  6000  0.586921     24000000
# 11  6500  0.613499     26000000
# 12  7000  0.633632     28000000
# Índice de correlación de Pearson: 0.9251895087542313
